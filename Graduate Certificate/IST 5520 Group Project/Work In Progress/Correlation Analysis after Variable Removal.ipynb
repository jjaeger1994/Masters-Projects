# %% [markdown]
# <h1 align="center"> Correlation Analysis After Removal of Multicollinearity Issues</h1>
# <h3 align="center"> IST 5520, 2021 Fall </h3>
# <h3 align="center"> Group 7 </h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pitchingdat = pd.read_csv(r"Multicollinearity_Removal_Pitching.csv", index_col = 0)
hittingdat = pd.read_csv(r"Multicollinearity_Removal_Hitting.csv", index_col = 0)

# %%
pitchingdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5503 entries, 0 to 5503
# Data columns (total 24 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   playerID   5503 non-null   object
#  1   yearID     5503 non-null   int64
#  2   GS         5503 non-null   int64
#  3   CG         5503 non-null   int64
#  4   SHO        5503 non-null   int64
#  5   SV         5503 non-null   int64
#  6   H          5503 non-null   int64
#  7   HR         5503 non-null   int64
#  8   BB         5503 non-null   int64
#  9   SO         5503 non-null   int64
#  10  BAOpp      5503 non-null   float64
#  11  ERA        5503 non-null   float64
#  12  WP         5503 non-null   int64
#  13  HBP        5503 non-null   int64
#  14  SH         5503 non-null   int64
#  15  SF         5503 non-null   int64
#  16  GIDP       5503 non-null   int64
#  17  LogSalary  5503 non-null   float64
#  18  nameFirst  5503 non-null   object
#  19  nameLast   5503 non-null   object
#  20  nameGiven  5503 non-null   object
#  21  throws     5503 non-null   object
#  22  teamName   5503 non-null   object
#  23  Win/Loss   5503 non-null   float64
# dtypes: float64(4), int64(14), object(6)
# memory usage: 1.0+ MB

# %%
hittingdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5373 entries, 0 to 5376
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   playerID   5373 non-null   object
#  1   yearID     5373 non-null   int64
#  2   R          5373 non-null   int64
#  3   RBI        5373 non-null   int64
#  4   SB         5373 non-null   int64
#  5   SO         5373 non-null   int64
#  6   IBB        5373 non-null   int64
#  7   SH         5373 non-null   int64
#  8   SF         5373 non-null   int64
#  9   GIDP       5373 non-null   int64
#  10  BA         5373 non-null   float64
#  11  OPS        5373 non-null   float64
#  12  LogSalary  5373 non-null   float64
#  13  nameFirst  5373 non-null   object
#  14  nameLast   5373 non-null   object
#  15  nameGiven  5373 non-null   object
#  16  bats       5373 non-null   object
#  17  teamName   5373 non-null   object
# dtypes: float64(3), int64(9), object(6)
# memory usage: 797.6+ KB

# %% [markdown]
# <h1 align="center"> Correlation Analysis on Pitching DataFrame</h1>

# %%
pitchingcorr = pitchingdat.corr(method = 'pearson')
pitchingcorr
# Out:
#              yearID        GS        CG       SHO        SV         H  \
# yearID     1.000000 -0.039453 -0.074836 -0.031498 -0.002294 -0.095696
# GS        -0.039453  1.000000  0.545993  0.444271 -0.250051  0.940954
# CG        -0.074836  0.545993  1.000000  0.760429 -0.118889  0.543952
# SHO       -0.031498  0.444271  0.760429  1.000000 -0.097669  0.428463
# SV        -0.002294 -0.250051 -0.118889 -0.097669  1.000000 -0.163993
# H         -0.095696  0.940954  0.543952  0.428463 -0.163993  1.000000
# HR        -0.092910  0.862481  0.442659  0.338464 -0.168446  0.890409
# BB        -0.115014  0.827625  0.390128  0.319638 -0.121398  0.843711
# SO         0.037742  0.828190  0.543718  0.449639 -0.020259  0.840356
# BAOpp     -0.113009  0.000337 -0.055625 -0.056274 -0.224493  0.001863
# ERA       -0.077145 -0.088974 -0.091740 -0.080718 -0.146983 -0.146931
# LogSalary  0.189821  0.226450  0.184020  0.247701   1.000000  0.098122
# Win/Loss   0.166318  0.167602  0.155927  0.241496   0.098122  1.000000

# %%
# Corralation Heatmap for Pitching
mask = np.zeros_like(pitchingdat.corr())
mask[np.triu_indices_from(mask)] = True

sns.heatmap(pitchingdat.corr(), cmap = 'RdYlGn', vmax = 1.0, mask = mask, linewidths = 2)

plt.yticks(rotation=0)
plt.xticks(rotation=45);

# %%
plt.figure(figsize = (25,15))
corrpitching = pitchingdat.corr()
sns.heatmap(corrpitching, annot = True, cmap = plt.cm.Reds)
plt.title("Correlation Analysis Heatmap on Pitching DataFrame")
plt.savefig('PitchingHeatmap2')
plt.show()

# %% [markdown]
# <h1 align="center"> Correlation Analysis on Hitting DataFrame</h1>

# %%
hittingcorr = hittingdat.corr(method = 'pearson')
hittingcorr
# Out:
#              yearID         R       RBI        SB        SO       IBB  \
# yearID     1.000000 -0.050042 -0.052702  0.010908  0.136903 -0.065922
# R         -0.050042  1.000000  0.891487  0.510781  0.775386  0.467698
# RBI       -0.052702  0.891487  1.000000  0.248448  0.770409  0.546578
# SB         0.010908  0.510781  0.248448  1.000000  0.330975  0.059915
# SO         0.136903  0.775386  0.770409  0.330975  1.000000  0.349722
# IBB       -0.065922  0.467698  0.546578  0.059915  0.349722  1.000000
# SH        -0.100219  0.136844 -0.061981  0.378698  0.024890 -0.133982
# SF        -0.037242  0.638135  0.715045  0.195208  0.514156  0.354880
# GIDP      -0.013746  0.651083  0.719885  0.125706  0.517093  0.373053
# BA        -0.096548  0.550710  0.516514  0.254201  0.335639  0.293836
# OPS       -0.098691  0.650734  0.676936  0.184019  0.506801  0.441762
# LogSalary  0.068632  0.387674  0.429678  0.062238  0.267556  0.317375
#
#                  SH        SF      GIDP        BA       OPS  LogSalary
# yearID    -0.100219 -0.037242 -0.013746 -0.096548 -0.098691   0.068632
# R          0.136844  0.638135  0.651083  0.550710  0.650734   0.387674
# RBI       -0.061981  0.715045  0.719885  0.516514  0.676936   0.429678
# SB         0.378698  0.195208  0.125706  0.254201  0.184019   0.062238
# SO         0.024890  0.514156  0.517093  0.335639  0.506801   0.267556
# IBB       -0.133982  0.354880  0.373053  0.293836  0.441762   0.317375
# SH         1.000000  0.026701  0.013006  0.088702 -0.070486  -0.132296
# SF         0.026701  1.000000  0.554432  0.374013  0.427029   0.331522
# GIDP       0.013006  0.554432  1.000000  0.427882  0.441951   0.383823
# BA         0.088702  0.374013  0.427882  1.000000  0.871452   0.241337
# OPS       -0.070486  0.427029  0.441951  0.871452  1.000000   0.320135
# LogSalary -0.132296  0.331522  0.383823  0.241337  0.320135   1.000000

# %%
# Corralation Heatmap for Hitting
mask2 = np.zeros_like(hittingdat.corr())
mask2[np.triu_indices_from(mask2)] = True

sns.heatmap(hittingdat.corr(), cmap = 'RdYlGn', vmax = 1.0, mask = mask2, linewidths = 2)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (20,10))
corrpitching = hittingdat.corr()
sns.heatmap(corrpitching, annot = True, cmap = plt.cm.Reds)
plt.title("Correlation Analysis Heatmap on Hitting DataFrame")
plt.savefig('HittingHeatmap2')
plt.show()
